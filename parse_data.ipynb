# %%
import json, ast
import pandas as pd

# %%
# data_path="new_data/"
# cmplt_path=data_path+"complete_data.json"
# labels_path=data_path+"labels.json"
# mapping_path=data_path+"url_map.txt"

# %%
# def get_map():
#     with open(mapping_path) as file:
#         return ast.literal_eval(file.read())

# def get_labels():
#     with open(labels_path) as file:
#         return json.loads(file.read())

# def get_complete_data():
#     with open(cmplt_path) as file:
#         x = file.read()
#     # x = x.replace("}\"", "}, \"")
#     x = x + ']'
#     return json.loads(x)

# %%
# mapping = get_map()
# labels = get_labels()

# %%
# cmplt_data = get_complete_data()

# %%
agg_pq = pd.read_parquet("data/media_agg.parquet")
pq = pd.read_parquet("data/media_agg_subtask3.parquet")

# %%
agg_pq
# Out:
#                 Economic  External_regulation_and_reputation  \
# source
# 01net           0.067429                            0.038420
# 021-rs          0.084747                            0.061279
# 100noticias     0.086654                            0.105577
# 101noticias     0.094182                            0.086191
# 1069-gr         0.107350                            0.048213
# ...                  ...                                 ...
# zp-comments     0.060090                            0.076403
# zpravy-tiscali  0.144322                            0.064362
# zueriost        0.084572                            0.059265
# zurnal24        0.114557                            0.059388
# zz              0.255565                            0.050572
#
#                 Capacity_and_resources  Political  Security_and_defense  \
# source
# 01net                         0.155781   0.256317              0.196081
# 021-rs                        0.132087   0.339001              0.172712
# 100noticias                   0.083256   0.331679              0.212413
# 101noticias                   0.122213   0.250989              0.247850
# 1069-gr                       0.224695   0.147547              0.261545
# ...                                ...        ...                   ...
# zp-comments                   0.035952   0.382018              0.242380
# zpravy-tiscali                0.125946   0.356827              0.153772
# zueriost                      0.202814   0.126715              0.358075
# zurnal24                      0.156209   0.266479              0.199793
# zz                            0.139153   0.302515              0.037132
#
#                 Quality_of_life  Policy_prescription_and_evaluation  \
# source
# 01net                  0.082394                            0.037535
# 021-rs                 0.052700                            0.030060
# 100noticias            0.039800                            0.032712
# 101noticias            0.051669                            0.031998
# 1069-gr                0.061864                            0.038252
# ...                         ...                                 ...
# zp-comments            0.029903                            0.028020
# zpravy-tiscali         0.039844                            0.025174
# zueriost               0.035619                            0.051364
# zurnal24               0.053281                            0.034163
# zz                     0.047836                            0.061706
#
#                 Legality_Constitutionality_and_jurisprudence  \
# source
# 01net                                               0.013207
# 021-rs                                              0.007300
# 100noticias                                         0.024611
# 101noticias                                         0.016306
# 1069-gr                                             0.006814
# ...                                                      ...
# zp-comments                                         0.028888
# zpravy-tiscali                                      0.007404
# zueriost                                            0.012113
# zurnal24                                            0.007047
# zz                                                  0.036002
#
#                 Cultural_identity  Fairness_and_equality  \
# source
# 01net                    0.013209               0.020416
# 021-rs                   0.014289               0.011574
# 100noticias              0.008217               0.008659
# 101noticias              0.009283               0.010117
# 1069-gr                  0.007743               0.007131
# ...                           ...                    ...
# zp-comments              0.006711               0.009012
# zpravy-tiscali           0.009056               0.006597
# zueriost                 0.013733               0.006777
# zurnal24                 0.012413               0.008906
# zz                       0.005702               0.011388
#
#                 Crime_and_punishment  Health_and_safety  Public_opinion  \
# source
# 01net                       0.010672           0.055991        0.021929
# 021-rs                      0.010124           0.047483        0.022437
# 100noticias                 0.014918           0.025724        0.011502
# 101noticias                 0.017442           0.032663        0.013994
# 1069-gr                     0.006309           0.064856        0.010668
# ...                              ...                ...             ...
# zp-comments                 0.030650           0.032195        0.022591
# zpravy-tiscali              0.006849           0.033185        0.017804
# zueriost                    0.004932           0.031782        0.008026
# zurnal24                    0.009396           0.049654        0.018130
# zz                          0.007681           0.026121        0.011328
#
#                 Morality
# source
# 01net           0.030618
# 021-rs          0.014207
# 100noticias     0.014276
# 101noticias     0.015103
# 1069-gr         0.007014
# ...                  ...
# zp-comments     0.015186
# zpravy-tiscali  0.008857
# zueriost        0.004212
# zurnal24        0.010584
# zz              0.007300
#
# [8318 rows x 14 columns]

# %%
try:
    agg_pq.loc['bbc']
except KeyError as e:
    print(e)

# %%
news_src = "https://www.foxnews.com/"

# %%
news_src.split("/")[2].repla
        width=500,ce("www.", '').replace('.com', '')
# Out:
# 'foxnews'

# %%
agg_pq["Economic"].keys().tolist()
# Out:
# ['01net',
#  '021-rs',
#  '100noticias',
#  '101noticias',
#  '1069-gr',
#  '112-international',
#  '112groningen',
#  '14ymedio',
#  '15min',
#  '15min-en',
#  '15min-ru',
#  '163',
#  '168chasa',
#  '1klik',
#  '1news',
#  '1prime',
#  '1tv',
#  '1tv-ge',
#  '1tv-ge-en',
#  '1tv-ge-ru',
#  '1voice',
#  '2020news-ge',
#  '2021portugal',
#  '20min',
#  '20minutes',
#  '20minutos',
#  '21dnn',
#  '237actu',
#  '237online',
#  '24-kg',
#  '24-kg-en',
#  '24-sapo',
#  '247libero',
#  '247newsbulletin',
#  '247ureports',
#  '24chasa',
#  '24h',
#  '24h-com',
#  '24heures',
#  '24hod',
#  '24kurier',
#  '24mk',
#  '24novini',
#  '24online',
#  '24ora-aw',
#  '24ovest',
#  '24plovdiv',
#  '24sata',
#  '24tv',
#  '24tv-ru',
#  '24ur',
#  '24zdrave',
#  '27-al',
#  '27avril',
#  '2anews',
#  '2duerighe',
#  '33live',
#  '360grade',
#  '360tv',
#  '373news',
#  '38fsvps',
#  '3dots',
#  '3dprintingindustry',
#  '3e-news',
#  '3mv',
#  '3szek',
#  '4-traders',
#  '444',
#  '451research',
#  '47news',
#  '5dias',
#  '5septiembre',
#  '62ua',
#  '65ymas',
#  '7info',
#  '7sur7',
#  '7sur7-cd',
#  '7thspace',
#  '81-cn',
#  '8sidor',
#  '96fm',
#  '972mag',
#  '98zero',
#  '9am',
#  '9colonne-it',
#  '9news',
#  'ABCDigital',
#  'ABCnews',
#  'AFCCRE',
#  'APS',
#  'ATAP-en',
#  'Aamulehti-fi',
#  'AbendBlatt',
#  'AerzteZeitung',
#  'AgrarHeute',
#  'Al-Watwan',
#  'AlphaTV',
#  'AntennaGR',
#  'AntenneDE',
#  'AsiaOne',
#  'BBJ',
#  'BT',
#  'BT-dk',
#  'BakhtarNewsAgency-en',
#  'BakhtarNewsAgency-ps',
#  'BalticNewsNetwork',
#  'BalticNewsService',
#  'BalticTimes',
#  'BangkokPost',
#  'Belta_be',
#  'Belta_deu',
#  'Belta_en',
#  'Belta_esp',
#  'BerlinMorgenpost',
#  'BernerZeitung',
#  'Beta-RS-sr',
#  'Brestskaia-Gazeta',
#  'BulgariaTelegraph-bg',
#  'BulgariaTelegraph-en',
#  'CBC',
#  'CBSnews',
#  'CCRTV',
#  'CERN',
#  'Cabinet-of-Ministers-ru',
#  'ChinaPost',
#  'CincoDias',
#  'Cor-EN',
#  'DGF',
#  'DGF-en',
#  'DRNyheder',
#  'DRNyheder-en',
#  'DagensIndustri',
#  'DagensNeringsliv',
#  'Db',
#  'DerBund',
#  'DiarioDeMallorca',
#  'DiarioVasco',
#  'Diena',
#  'DnevniList-sr',
#  'Dnevnik',
#  'Dnevnik-BG',
#  'EC',
#  'ETUC',
#  'EastAfrican',
#  'ElComercio',
#  'ElMercurioOnline',
#  'ElPaisUY',
#  'EuroPA',
#  'Europe1',
#  'Europeiskakommissionen',
#  'Evertiq',
#  'Evertiq-pl',
#  'Expansion',
#  'FCK-fullfact',
#  'FCK-rtlLuxembourg',
#  'FCK-today-rtlLuxembourg',
#  'FZ',
#  'FaroDeVigo',
#  'FinancialMirror',
#  'GF',
#  'GI',
#  'GazzettaDelSud',
#  'GolosArmeniiMain',
#  'Gomelskaia-Pravda',
#  'GulfDailyNews',
#  'HO',
#  'Handelsblatt',
#  'HindustanTimes',
#  'HonululuAdvertiser',
#  'HoyDigital',
#  'HoyDigital-DO',
#  'HumanRightsWatch',
#  'IDF',
#  'IGNS',
#  'IREO',
#  'ISN',
#  'IlFoglio',
#  'IlGazzettino',
#  'IltaSanomat',
#  'JakartaPost',
#  'KPMG',
#  'KosovaLive',
#  'Ksta',
#  'LaNazione',
#  'LaPresse',
#  'LaRazon',
#  'LaTercera',
#  'LeBien',
#  'LeMonde',
#  'LeMonde-en',
#  'LePoint',
#  'LesEchos',
#  'Lex-bg',
#  'Liberation',
#  'MDR',
#  'MSF',
#  'MSF-be',
#  'MSF-ca',
#  'MSF-de',
#  'MSF-es',
#  'MSF-fr',
#  'MaltaIndipendent',
#  'MaltaToday',
#  'MayoNews',
#  'MelillaHoy',
#  'NZZ',
#  'Newslab',
#  'NuclearThreatInitiative',
#  'ORF',
#  'OuestFrance',
#  'Ppr',
#  'PraguePost',
#  'Publico-ES',
#  'Publico-PT',
#  'Quotidianodibari',
#  'RF',
#  'RP',
#  'RTERadio',
#  'RTLFrance',
#  'RegionDigital',
#  'SVTSweden',
#  'Salzburger',
#  'Sana-en',
#  'Sana-es',
#  'Sana-fr',
#  'Sana-tr',
#  'Stuff',
#  'Svampriket',
#  'Sydsvenskan',
#  'TF1',
#  'TO',
#  'TT',
#  'Tagespiegel',
#  'TelegrammeDeBrest',
#  'TheFrontierPost-en',
#  'TheScotsman',
#  'TonsbergsBlad',
#  'TorontoStar',
#  'Triniad-guardian',
#  'UltimaHora',
#  'UnioneSarda',
#  'Uusimaa',
#  'VG',
#  'Vechernii-Grodno',
#  'VilaWeb',
#  'Vorarlberg',
#  'WarsawBusiness',
#  'Welt',
#  'Whitehouse',
#  'WortLuxembourg',
#  'WortLuxembourg-en',
#  'WortLuxembourg-fr',
#  'WortLuxembourg-pt',
#  'YorkshirePost',
#  'ZDF',
#  'a1',
#  'a1on',
#  'a1plus',
#  'aa',
#  'aa-en',
#  'aa-fr',
#  'aaea',
#  'aafarmer',
#  'aalto.fi',
#  'aap-au',
#  'aawsat',
#  'abamako',
#  'abangui',
#  'abc-Andalucia',
#  'abc-au',
#  'abc-az',
#  'abc-br',
#  'abc7ny',
#  'abcactionnews',
#  'abcnews-al',
#  'abcnyheter-no',
#  'abendzeitung-muenchen',
#  'aber',
#  'abi',
#  'abidjan',
#  'abidjantv',
#  'abkhazeti',
#  'abkhazinform',
#  'abola',
#  'abounderrattelser',
#  'aboutpharma',
#  'abruzzoindependent',
#  'abs-cbnnews',
#  'absatzwirtschaft',
#  'abstvradio',
#  'accent',
#  'accesswdun',
#  'accountancyvanmorgen',
#  'accountant',
#  'acento',
#  'acn',
#  'acores24horas',
#  'acorianooriental',
#  'acotonou',
#  'acpcongo',
#  'acritica',
#  'acs',
#  'actionnewsjax',
#  'activa',
#  'actmedia-eu',
#  'actu',
#  'actu-environnement',
#  'actu-togo',
#  'actualcomment',
#  'actualdecluj',
#  'actualidadaeroespacial',
#  'actualitateaprahoveana',
#  'actualite-cd',
#  'actualno',
#  'actubenin',
#  'actugeeks',
#  'actuguinee',
#  'actuniger',
#  'actuprime',
#  'ad',
#  'adaderana',
#  'adakar',
#  'adevarul',
#  'adiac-congo',
#  'adigeatoday',
#  'adjaratv',
#  'adl',
#  'adm.gov',
#  'admin',
#  'adncuba',
#  'adnkronos',
#  'adnmundo',
#  'adnradio',
#  'adozona',
#  'adressa',
#  'adslzone',
#  'advance',
#  'advfn',
#  'advocatie',
#  'advokaten',
#  'aefinfo',
#  'aeidl',
#  'aeiou',
#  'aenverde',
#  'aerialfiremag',
#  'aerotechnews',
#  'affarerinorr',
#  'affaritaliani',
#  'affaritecnici',
#  'affarsvarlden',
#  'afghanistan',
#  'afghanistan-analysts',
#  'afghanistantimes',
#  'afloat',
#  'afn',
#  'afp',
#  'afp-english',
#  'afp-espanol',
#  'afp-portugues',
#  'afrasiabank',
#  'africa',
#  'africa-cgtn',
#  'africa-newsroom',
#  'africacenter',
#  'africaeaffari',
#  'africafeeds',
#  'africaguinee',
#  'africain',
#  'africaintelligence',
#  'africanbusinessmagazine',
#  'africanewswire',
#  'africanmanager',
#  'africaports-za',
#  'africavision7',
#  'afrique-asie',
#  'afrique-lalibre',
#  'afrique-latribune',
#  'afrique-sur7',
#  'afriqueeducation',
#  'afriquesenlutte',
#  'aftenbladet',
#  'aftenposten',
#  'aftonbladet',
#  'agara',
#  'agefi',
#  'agencecamerounpresse',
#  'agenceecofin',
#  'agenceurope',
#  'agenceurope-en',
#  'agenciabrasil',
#  'agenciaoglobo',
#  'agenciasinc',
#  'agenda-ge',
#  'agendadigitale',
#  'agendasustentable',
#  'agenparl',
#  'agenpress',
#  'agensir',
#  'agentura-ru',
#  'agenziacomunica',
#  'agenzianova',
#  'agerpres',
#  'agerpres-en',
#  'agf',
#  'agfax',
#  'agfundernews',
#  'agi',
#  'agipronews',
#  'agoramt',
#  'agoravox',
#  'agoravox-fr',
#  'agpb',
#  'agpguinee',
#  'agprofessional',
#  'agr',
#  'agra',
#  'agrapress',
#  'agrar-presseportal',
#  'agrarszektor',
#  'agrarzeitung',
#  'agri-pulse',
#  'agribusinessglobal',
#  'agricolae',
#  'agricultura',
#  'agriculturaemar',
#  'agriculture-environnement',
#  'agriculture-strategies',
#  'agriculture-successful-farming',
#  'agriculturejournals-agricecon',
#  'agridees',
#  'agridigitale',
#  'agrifoodtoday',
#  'agrifutures',
#  'agrigentonotizie',
#  'agrigentooggi',
#  'agrigiornale',
#  'agriholland',
#  'agriland',
#  'agriland-co-uk',
#  'agrimpresaonline',
#  'agriorbit',
#  'agripress',
#  'agris-fao',
#  'agrisole',
#  'agriterra',
#  'agritotal',
#  'agriview',
#  'agro-bg',
#  'agro-business-ro',
#  'agro-media',
#  'agroavances',
#  'agroberichtenbuitenland',
#  'agrobusiness',
#  'agrocampana',
#  'agrocapital',
#  'agroclave',
#  'agroclm',
#  'agrodiario',
#  'agrodiariohuelva',
#  'agrodigital',
#  'agroempresario',
#  'agroforum',
#  'agrofy',
#  'agroinfo',
#  'agroinform',
#  'agroinformacion',
#  'agroinsurance',
#  'agroinsurance-en',
#  'agrointel',
#  'agroklub',
#  'agroklub-rs',
#  'agronaplo',
#  'agronegocios',
#  'agronews',
#  'agronews-pl',
#  'agronewscastillayleon',
#  'agronewscomunitatvalenciana',
#  'agronigeria',
#  'agronline',
#  'agronoticias',
#  'agronovinite',
#  'agropages',
#  'agroplovdiv',
#  'agropolska',
#  'agropopular',
#  'agroportal',
#  'agroprofil',
#  'agropublic',
#  'agrotec',
#  'agrotv',
#  'agrotypos',
#  'agrovoice',
#  'agroxxi',
#  'agrozona',
#  'agweb',
#  'ahewar',
#  'ahram',
#  'ahram-EN',
#  'aiaaira',
#  'aib',
#  'aiccre',
#  'aidas',
#  'aif',
#  'aif-by',
#  'aigaiotv',
#  'aikenstandard',
#  'aimdigital',
#  'ain',
#  'aip',
#  'aip-ci',
#  'airforcemag',
#  'airforcetechnology',
#  'airforcetimes',
#  'airliquide',
#  'airport-world',
#  'airrecognition',
#  'airuniversity',
#  'aise',
#  'aiz',
#  'ajw',
#  'aka-Apropos',
#  'akademikern',
#  'akcent',
#  'akhbaar',
#  'akhbaralyom',
#  'akipress',
#  'akipress-en',
#  'akkerbouwactueel',
#  'akkerbouwbedrijf',
#  'akkerwijzer',
#  'akp-en',
#  'akroama',
#  'aktiespararna',
#  'aktuality',
#  'aktualne',
#  'aktualne-sk',
#  'aktuellhallbarhet',
#  'aktuelno',
#  'akzonobel',
#  'al',
#  'al-akhbar',
#  'al-khaleej',
#  'al-monitor',
#  'al-wihda',
#  'alanba',
#  'alandstidningen',
#  'alaniainform',
#  'alankabout',
#  'alarabiya',
#  'alarabiya-en',
#  'alaraby',
#  'albaniannews',
#  'albawaba-ar',
#  'albawaba-en',
#  'albawabhnews',
#  'albayane',
#  'albeu',
#  'alchourouk',
#  'alert24',
#  'alerteinfo',
#  'alfa',
#  'alfahir',
#  'alfavita',
#  'algeriawatch',
#  'algerie-focus',
#  'algeriemondeinfos',
#  'algeriepatriotique',
#  'alghad',
#  'alghad-oman',
#  'alghad-oman-en',
#  'alhourriah',
#  'alibreville',
#  'alicanteplaza',
#  'alicantur',
#  'alimarket',
#  'alimentando',
#  'alimente',
#  'aliwaa',
#  'aljazeera',
#  'aljazeera-en',
#  'all-kharkov',
#  'allaboutfeed',
#  'allafrica',
#  'allea',
#  'allehanda',
#  'alliancemagazine',
#  'allnews',
#  'allnews-ch',
#  'almanar-en',
#  'almanar-fr',
#  'almayadeen',
#  'almayadeen-en',
#  'almega',
#  'almomento',
#  'alo',
#  'alome',
#  'alphafreepress',
#  'alphagalileo',
#  'alphanews',
#  'alphapatras',
#  'alquds-uk',
#  'alsat-m',
#  'alsfelder-allgemeine',
#  'alsumaria',
#  'altapress-ru',
#  'altenergymag',
#  'alternativenergia',
#  'alternatives-economiques',
#  'alternet',
#  'alterpresse',
#  'altinget',
#  'altoadige',
#  'altreconomia',
#  'alvorada',
#  'alwatannews',
#  'alytausnaujienos',
#  'am',
#  'amalfinotizie-it',
#  'amandala',
#  'amazonia',
#  'amazoniareal',
#  'ambiente-tiscali-it',
#  'ambienteambienti',
#  'ambientemagazine',
#  'ambientesicurezzaweb',
#  'ambientum',
#  'ambito',
#  'amcham',
#  'america-energias-renovables',
#  'america-retail',
#  'americaeconomia',
#  'american-club',
#  'americanprogress',
#  'americansecurityproject',
#  'americatv',
#  'amerika21',
#  'amerikiskhma',
#  'ami',
#  'amin',
#  'aminata',
#  'amisdelaterre',
#  'ammannet',
#  'ammonnews-en',
#  'amnesty-en',
#  'amnesty-es',
#  'amnesty-fr',
#  'amta',
#  'amti',
#  'amtsavisen',
#  'an-online',
#  'analisidifesa',
#  'analitica',
#  'analyticsinsight',
#  'anbud24',
#  'anconatoday',
#  'andaluciainformacion',
#  'andoveradvertiser',
#  'andrewerickson',
#  'anexartitos',
#  'anglocelt',
#  'angola-online',
#  'angola24horas',
#  'angop-pt',
#  'anguillian',
#  'animalpolitico',
#  'aninews',
#  'anmvioggi',
#  'annahar',
#  'annistonstar',
#  'annoeuropeocittadini',
#  'anp-ne',
#  'ans',
#  'ansa',
#  'ansa-Europa',
#  'ansabrasil',
#  'ansamed',
#  'ansamed-it',
#  'ansvsa',
#  'ant1iwo',
#  'antaranews',
#  'antaranews-en',
#  'antena3',
#  'antena3noticias',
#  'antenasatelor',
#  'antennaunonotizie',
#  'anti-empire',
#  'anti-k',
#  'antiguaobserver',
#  'antimafiaduemila',
#  'aostaoggi',
#  'aostasera',
#  'aouaga',
#  'ap22',
#  'ap3',
#  'ap3-ru',
#  'apa',
#  'apache-be',
#  'apanews-en',
#  'apasec',
#  'apc',
#  'apcss',
#  'apecs',
#  'apiavirtual',
#  'apiceuropa',
#  'apital',
#  'apk-inform',
#  'apk-inform-ru',
#  'aplatanaonews',
#  'aplazio',
#  'apn',
#  'apnews',
#  'apollo',
#  'aporrea',
#  'app-en',
#  'appelloalpopolo',
#  'aps-dz',
#  'apsny',
#  'apsny-ru',
#  'apsnypress',
#  'apsnypress-ap',
#  'apsua',
#  'apublica',
#  'aquieuropa',
#  'aquilon',
#  'ar-timesofisrael',
#  'ara-reuters',
#  'arabcenterdc',
#  'arabnews',
#  'arabnews-fr',
#  'arabs48',
#  'arabtimes',
#  'aradon',
#  'aragonhoy',
#  'araratonline',
#  'aratta',
#  'arbejderen',
#  'arbetarbladet',
#  'arbetaren',
#  'arbetet',
#  'arbetsvarlden',
#  'arcadiaportal-gr',
#  'archiwumosiatynskiego',
#  'archyde',
#  'arcinfo',
#  'arcor',
#  'arctic-ru',
#  'arctictoday',
#  'ardanews',
#  'areion24',
#  'arezzoweb',
#  'argatoscana',
#  'argolika',
#  'arib-info',
#  'arileht',
#  'arka-am-en',
#  'arka-am-ru',
#  'arkansasonline',
#  'arlingtoninstitute',
#  'armadainternational',
#  'armenews',
#  'armenpress',
#  'armenpress-ru',
#  'armradio',
#  'armscontrol',
#  'armscontrolwonk',
#  'armyrecognition',
#  'armytechnology',
#  'armytimes',
#  'armyupress',
#  'arnnet',
#  'arstechnica',
#  'articolo21',
#  'articulo66',
#  'artribune',
#  'artslife',
#  'arvopaperi',
#  'as-coa',
#  'asahi-JP',
#  'asaja',
#  'asajacyl',
#  'asambleanacional',
#  'asbeiras',
#  'ascolinotizie',
#  'asdnews',
#  'asemana',
#  'asenovgrad-net',
#  'asianage',
#  'asiancorrespondent',
#  'asianews',
#  'asianews-en',
#  'asiantrader',
#  'asiatimes',
#  'askanews',
#  'asme',
#  'asn24',
#  'aspi',
#  'aspistrategist',
#  'assabah',
#  'assahifa',
#  'assetnews',
#  'assirou',
#  'associazioneitaliananucleare',
#  'astanatimes',
#  'astronautinews',
#  'asvis',
#  'at5',
#  'ata-en',
#  'atalayar',
#  'atarde',
#  'athina984',
#  'atitudinea',
#  'atl',
#  'atlanticcouncil',
#  'atlantico',
#  'atn-ua',
#  'atoo',
#  'atvbl',
#  'au',
#  'augsburger-allgemeine',
#  'aujourdhui',
#  'ausertimes',
#  'ausgestrahlt',
#  'austagderblad',
#  'authorityngr',
#  'auto-idnes',
#  'autoactu',
#  'autoblog',
#  'autobranchendanmark',
#  'autocar',
#  'autocomponentsindia',
#  'automobielmanagement',
#  'automobil-produktion',
#  'automobilwoche',
#  'automotive-management',
#  'autonews',
#  'autonewschina',
#  'autoplus',
#  'avaasaja',
#  'avante',
#  'avanti',
#  'avanza',
#  'avaruus',
#  'avaz',
#  'avaz-english',
#  'avellinotoday',
#  'avesta',
#  'avgi',
#  'avhandlingar',
#  'aviaciondigital',
#  'aviation-direct',
#  'aviation24',
#  'aviationweek',
#  'avicultura',
#  'avisen',
#  'avn',
#  'avto',
#  'avto-magazin',
#  'avtomobilizem',
#  'avvenire',
#  'avveniredicalabria',
#  'axess',
#  'axiaplus',
#  'aydinses',
#  'az-online',
#  'az-web',
#  'azactu',
#  'azattyk',
#  'azatutyun-am',
#  'azatutyun-en',
#  'azcentral',
#  'azernews',
#  'azertag',
#  'azertag-fr',
#  'azh',
#  'azom',
#  'azomining',
#  'azonline',
#  'azonnali',
#  'aztecanoticias',
#  'b1',
#  'b92net_en',
#  'b92net_sr',
#  'babruysk',
#  'backnetz',
#  'badische-zeitung',
#  'bahamas-gov',
#  'baidu',
#  'baikal-daily',
#  'bairdmaritime',
#  'bakeryandsnacks',
#  'balkangreenenergynews',
#  'balkaninsight',
#  'balkanist',
#  'balkanscourriers',
#  'balkanweb',
#  'balochistan24',
#  'balochwarna',
#  'balsas',
#  'baltictransportjournal',
#  'baltimore-cbslocal',
#  'baltische-rundschau',
#  'bama',
#  'bamada',
#  'band',
#  'bangkokbiznews',
#  'bangordailynews',
#  'banken',
#  'banker',
#  'bankier',
#  'bankinformation',
#  'bankinfosecurity',
#  'bankingnews',
#  'bankir',
#  'banknews',
#  'banks',
#  'banksnews',
#  'bankwatch',
#  'banouto',
#  'baon',
#  'baraondanews',
#  'baritoday',
#  'barnet-today',
#  'barneveld-nieuws-nl',
#  'barometern',
#  'barrie',
#  'barrigaverde',
#  'barrons',
#  'basicint',
#  'basilicata24',
#  'basnews-kr',
#  'bathchronicle',
#  'batteryindustry',
#  'batumelebi',
#  'baublatt-ch',
#  'bauernzeitung',
#  'bauernzeitung-ch',
#  'bay',
#  'bayerische-staatszeitung',
#  'baz',
#  'bbc',
#  'bbc-chinese',
#  'bbc-es',
#  'bbc-french-africa',
#  'bbc-persian',
#  'bbc-portuguese-brasil',
#  'bbc-russian',
#  'bbc-spanish',
#  'bbc-swahili',
#  'bbc-turkce',
#  'bbc-vietnam',
#  'bbchealth',
#  'bblat',
#  'bbntimes',
#  'bbv-net',
#  'bcg',
#  'bdg',
#  'bdnews24',
#  'bdonline',
#  'bdpst24',
#  'beat102103',
#  'beefcentral',
#  'beefpoint',
#  'behoerden-spiegel',
#  'beijingreview',
#  'beijingreview-en',
#  'beijingreview-fr',
#  'beijingreview-ja',
#  'belapan',
#  'belaruspartisan',
#  'belfastlive',
#  'belfasttelegraph',
#  'belfercenter',
#  'belgazeta',
#  'bellingcat',
#  'bellona',
#  'beloitdailynews',
#  'bemanningsforetagen',
#  'bemparana',
#  'benarnews',
#  'bendbulletin',
#  'benininfo',
#  'beninwebtv',
#  'benzinga',
#  'beobachternews',
#  'beol',
#  'bequoted',
#  'bergamonews',
#  'bergsmannen',
#  'berlin',
#  'berliner-zeitung',
#  'berlingske',
#  'bernama',
#  'bertelsmann-stiftung',
#  'besoksliv',
#  'best-tv',
#  'bestmag',
#  'betanews',
#  'beuc',
#  'beveragedaily',
#  'bezpecnostpotravin',
#  ...]

# %%
pq
# Out:
#                 labels.Appeal_to_Authority  labels.Appeal_to_Popularity  \
# source
# 01net                                    0                            0
# 021-rs                                   0                            0
# 100noticias                              0                            0
# 101noticias                              2                            0
# 1069-gr                                  0                            0
# ...                                    ...                          ...
# zp-comments                              0                            0
# zpravy-tiscali                           0                            0
# zueriost                                 8                            0
# zurnal24                                 0                            0
# zz                                       0                            0
#
#                 labels.Appeal_to_Values  labels.Appeal_to_Fear-Prejudice  \
# source
# 01net                                 2                               19
# 021-rs                               35                              635
# 100noticias                          46                              300
# 101noticias                          23                              544
# 1069-gr                              29                              630
# ...                                 ...                              ...
# zp-comments                          34                              633
# zpravy-tiscali                       37                              272
# zueriost                             11                               37
# zurnal24                             20                              287
# zz                                    1                                2
#
#                 labels.Flag_Waving  labels.Causal_Oversimplification  \
# source
# 01net                            0                                 0
# 021-rs                          65                                 0
# 100noticias                     59                                 0
# 101noticias                     58                                 0
# 1069-gr                         34                                 0
# ...                            ...                               ...
# zp-comments                     89                                 0
# zpravy-tiscali                  52                                 0
# zueriost                        14                                 0
# zurnal24                        18                                 0
# zz                               1                                 0
#
#                 labels.False_Dilemma-No_Choice  \
# source
# 01net                                        0
# 021-rs                                       2
# 100noticias                                  1
# 101noticias                                  0
# 1069-gr                                      3
# ...                                        ...
# zp-comments                                  1
# zpravy-tiscali                               0
# zueriost                                     0
# zurnal24                                     0
# zz                                           0
#
#                 labels.Consequential_Oversimplification  labels.Straw_Man  \
# source
# 01net                                                 3                 0
# 021-rs                                                8                 0
# 100noticias                                           2                 0
# 101noticias                                           3                 0
# 1069-gr                                              11                 0
# ...                                                 ...               ...
# zp-comments                                         216                 0
# zpravy-tiscali                                        2                 0
# zueriost                                              0                 0
# zurnal24                                             15                 0
# zz                                                    0                 0
#
#                 labels.Red_Herring  ...  labels.Conversation_Killer  \
# source                              ...
# 01net                            0  ...                           1
# 021-rs                           0  ...                           9
# 100noticias                      0  ...                           3
# 101noticias                      0  ...                           3
# 1069-gr                          0  ...                           5
# ...                            ...  ...                         ...
# zp-comments                      0  ...                          33
# zpravy-tiscali                   0  ...                           7
# zueriost                         0  ...                           0
# zurnal24                         0  ...                           1
# zz                               0  ...                           0
#
#                 labels.Loaded_Language  labels.Repetition  \
# source
# 01net                               41                  0
# 021-rs                             875                  0
# 100noticias                        702                  0
# 101noticias                       1315                  0
# 1069-gr                           1389                  0
# ...                                ...                ...
# zp-comments                       2936                  0
# zpravy-tiscali                     403                  0
# zueriost                            15                  0
# zurnal24                           301                  0
# zz                                   5                  0
#
#                 labels.Exaggeration-Minimisation  \
# source
# 01net                                          3
# 021-rs                                        31
# 100noticias                                   24
# 101noticias                                   61
# 1069-gr                                       73
# ...                                          ...
# zp-comments                                   69
# zpravy-tiscali                                16
# zueriost                                       1
# zurnal24                                       6
# zz                                             0
#
#                 labels.Obfuscation-Vagueness-Confusion  \
# source
# 01net                                                0
# 021-rs                                               0
# 100noticias                                          0
# 101noticias                                          0
# 1069-gr                                              0
# ...                                                ...
# zp-comments                                          0
# zpravy-tiscali                                       0
# zueriost                                             0
# zurnal24                                             0
# zz                                                   0
#
#                 labels.Name_Calling-Labeling  labels.Doubt  \
# source
# 01net                                      9             3
# 021-rs                                   632           227
# 100noticias                              173            32
# 101noticias                              308            88
# 1069-gr                                  392           252
# ...                                      ...           ...
# zp-comments                              722          1542
# zpravy-tiscali                           202            62
# zueriost                                 163            19
# zurnal24                                 122           201
# zz                                         1             0
#
#                 labels.Guilt_by_Association  labels.Appeal_to_Hypocrisy  \
# source
# 01net                                     1                           0
# 021-rs                                   12                           1
# 100noticias                               4                           0
# 101noticias                               3                           2
# 1069-gr                                   9                           1
# ...                                     ...                         ...
# zp-comments                               3                           3
# zpravy-tiscali                            7                           0
# zueriost                                  0                           0
# zurnal24                                  3                           0
# zz                                        0                           0
#
#                 labels.Questioning_the_Reputation
# source
# 01net                                           2
# 021-rs                                         68
# 100noticias                                    20
# 101noticias                                    28
# 1069-gr                                        44
# ...                                           ...
# zp-comments                                   617
# zpravy-tiscali                                 12
# zueriost                                       11
# zurnal24                                       33
# zz                                              0
#
# [8302 rows x 23 columns]

# %%
pq.columns = [i.replace('labels.', '') for i in pq.columns.tolist()]

# %%
from courlan import check_url

print(check_url('https://www.bbc.com/news'))
# Out:
# ('https://www.bbc.com/news', 'bbc.com')

# %%
pq
# Out:
#                 Appeal_to_Authority  Appeal_to_Popularity  Appeal_to_Values  \
# source
# 01net                             0                     0                 2
# 021-rs                            0                     0                35
# 100noticias                       0                     0                46
# 101noticias                       2                     0                23
# 1069-gr                           0                     0                29
# ...                             ...                   ...               ...
# zp-comments                       0                     0                34
# zpravy-tiscali                    0                     0                37
# zueriost                          8                     0                11
# zurnal24                          0                     0                20
# zz                                0                     0                 1
#
#                 Appeal_to_Fear-Prejudice  Flag_Waving  \
# source
# 01net                                 19            0
# 021-rs                               635           65
# 100noticias                          300           59
# 101noticias                          544           58
# 1069-gr                              630           34
# ...                                  ...          ...
# zp-comments                          633           89
# zpravy-tiscali                       272           52
# zueriost                              37           14
# zurnal24                             287           18
# zz                                     2            1
#
#                 Causal_Oversimplification  False_Dilemma-No_Choice  \
# source
# 01net                                   0                        0
# 021-rs                                  0                        2
# 100noticias                             0                        1
# 101noticias                             0                        0
# 1069-gr                                 0                        3
# ...                                   ...                      ...
# zp-comments                             0                        1
# zpravy-tiscali                          0                        0
# zueriost                                0                        0
# zurnal24                                0                        0
# zz                                      0                        0
#
#                 Consequential_Oversimplification  Straw_Man  Red_Herring  ...  \
# source                                                                    ...
# 01net                                          3          0            0  ...
# 021-rs                                         8          0            0  ...
# 100noticias                                    2          0            0  ...
# 101noticias                                    3          0            0  ...
# 1069-gr                                       11          0            0  ...
# ...                                          ...        ...          ...  ...
# zp-comments                                  216          0            0  ...
# zpravy-tiscali                                 2          0            0  ...
# zueriost                                       0          0            0  ...
# zurnal24                                      15          0            0  ...
# zz                                             0          0            0  ...
#
#                 Conversation_Killer  Loaded_Language  Repetition  \
# source
# 01net                             1               41           0
# 021-rs                            9              875           0
# 100noticias                       3              702           0
# 101noticias                       3             1315           0
# 1069-gr                           5             1389           0
# ...                             ...              ...         ...
# zp-comments                      33             2936           0
# zpravy-tiscali                    7              403           0
# zueriost                          0               15           0
# zurnal24                          1              301           0
# zz                                0                5           0
#
#                 Exaggeration-Minimisation  Obfuscation-Vagueness-Confusion  \
# source
# 01net                                   3                                0
# 021-rs                                 31                                0
# 100noticias                            24                                0
# 101noticias                            61                                0
# 1069-gr                                73                                0
# ...                                   ...                              ...
# zp-comments                            69                                0
# zpravy-tiscali                         16                                0
# zueriost                                1                                0
# zurnal24                                6                                0
# zz                                      0                                0
#
#                 Name_Calling-Labeling  Doubt  Guilt_by_Association  \
# source
# 01net                               9      3                     1
# 021-rs                            632    227                    12
# 100noticias                       173     32                     4
# 101noticias                       308     88                     3
# 1069-gr                           392    252                     9
# ...                               ...    ...                   ...
# zp-comments                       722   1542                     3
# zpravy-tiscali                    202     62                     7
# zueriost                          163     19                     0
# zurnal24                          122    201                     3
# zz                                  1      0                     0
#
#                 Appeal_to_Hypocrisy  Questioning_the_Reputation
# source
# 01net                             0                           2
# 021-rs                            1                          68
# 100noticias                       0                          20
# 101noticias                       2                          28
# 1069-gr                           1                          44
# ...                             ...                         ...
# zp-comments                       3                         617
# zpravy-tiscali                    0                          12
# zueriost                          0                          11
# zurnal24                          0                          33
# zz                                0                           0
#
# [8302 rows x 23 columns]

# %%
df = pd.read_csv("data/eu_data.csv", usecols=["link", "source"])

# %%
df.columns
# Out:
# Index(['id', 'guid', 'title', 'link', 'pubDate', 'description', 'source',
#        'language', 'text', 'country', 'country_code'],
#       dtype='object')

# %%
df = df.drop_duplicates(subset=["source"])

# %%
df_new = df.set_index('source').join(pq)

# %%
def get_base_url(x):
    baseurl = check_url(x)
    if baseurl:
        baseurl = baseurl[1]
        return x.split(str(baseurl))[0] + baseurl
    else:
        return x

# %%
df_new.link = df_new.link.apply(lambda x: get_base_url(x))

# %%
df_new_new = df_new.set_index("link")

# %%
df_new_new.to_parquet("data/linkmapped_eu_data.parquet")

# %%
basemapped_to_link = dict(df_new.link)

# %%
basemapped_to_link = {v: k for k, v in basemapped_to_link.items()}

# %%
basemapped_to_link
# Out:
# {'https://www.ibtimes.com': 'ibtimes',
#  'https://ma7.sk': 'ma7-sk',
#  'https://nova.bg': 'kanal3',
#  'https://www.se.pl': 'se',
#  'https://www.trud.ru': 'trud',
#  'https://www.saltwire.com': 'thechronicleherald',
#  'https://www.tellerreport.com': 'tellerreport',
#  'https://www.24sata.hr': '24sata',
#  'https://www.agenzianova.com': 'agenzianova',
#  'https://www.coastfm.co.uk': 'coastfm',
#  'https://fai.informazione.it': 'fai.informazione',
#  'https://www.nu.nl': 'nu',
#  'https://dialogos.com.cy': 'dialogos',
#  'https://www.japantimes.co.jp': 'japantimes',
#  'https://www.justsecurity.org': 'justsecurity',
#  'https://thepeninsulaqatar.com': 'thepeninsulaqatar',
#  'https://www.diariosigloxxi.com': 'diariosigloxxi',
#  'https://www.documentonews.gr': 'documentonews',
#  'https://www.elextremosur.com': 'elextremosur',
#  'https://www.metro.us': 'metro-us',
#  'https://morningexpress.in': 'morningexpress',
#  'https://ketrzyn.naszemiasto.pl': 'naszemiastoketrzyn',
#  'http://www.newsincyprus.com': 'newsincyprus-greek',
#  'https://yle.fi': 'yle',
#  'https://elpais.com': 'elpais-latinoamerica',
#  'https://elvenezolanonews.com': 'elvenezolanonews',
#  'https://www.iconaclima.it': 'iconaclima',
#  'https://www.inewsgr.com': 'inews-gr',
#  'https://www.whitehouse.gov': 'Whitehouse',
#  'https://www.brief.com.cy': 'brief-cy',
#  'https://headtopics.com': 'headtopics',
#  'https://www.heraldsun.com.au': 'heraldsun',
#  'https://www.lanacion.com.ar': 'lanacion-AR',
#  'https://www.madata.gr': 'madata',
#  'https://www.tportal.hr': 'tportal',
#  'https://www.sohu.com': 'yule-sohu',
#  'https://www.agriland.ie': 'agriland',
#  'https://www.delfi.lt': 'delfi-en',
#  'https://kvedomosti.ru': 'kvedomosti',
#  'https://noticiassin.com': 'noticiassin',
#  'https://www.reuters.com': 'ara-reuters',
#  'https://sciencebusiness.net': 'sciencebusiness',
#  'https://www.ukrinform.net': 'ukrinform',
#  'https://www.zawya.com': 'zawya-palestine',
#  'https://www.zazoom.it': 'zazoom-it',
#  'https://eurozpravy.cz': 'eurozpravy',
#  'http://fr.le360.ma': 'le360',
#  'https://finance.yahoo.com': 'en-finance-yahoo',
#  'https://www.news.com.au': 'news_com_au',
#  'https://www.total-croatia-news.com': 'total-croatia-news',
#  'https://www.nicematin.com': 'nicematin',
#  'https://www.reporter.gr': 'reporter-gr',
#  'https://www.usnews.com': 'usnews',
#  'https://www.wsj.com': 'wsj-en',
#  'https://www.marketscreener.com': '4-traders',
#  'https://abcnews.go.com': 'ABCnews',
#  'https://www.diariolasamericas.com': 'diariolasamericas',
#  'https://emea.gr': 'emea',
#  'https://epiloges.tv': 'epiloges',
#  'https://fr.euronews.com': 'euronews-fr',
#  'https://lenexweb.com': 'lenexweb',
#  'https://slovodel.com': 'slovodel',
#  'https://meduza.io': 'meduza',
#  'https://www.newsbreak.gr': 'newsbreak',
#  'https://www.tvsvizzera.it': 'tvsvizzera',
#  'https://www.ant1news.gr': 'AntennaGR',
#  'https://www.connaissancedesenergies.org': 'connaissancedesenergies',
#  'https://www.diariocolatino.com': 'diariocolatino',
#  'https://www.ilsole24ore.com': 'scuola24',
#  'https://es.investing.com': 'investing-ES',
#  'https://www.lorientlejour.com': 'lorientlejour',
#  'https://www.teleprensa.com': 'teleprensa',
#  'https://whatsnew2day.com': 'whatsnew2day',
#  'https://www.dnevnik.bg': 'Dnevnik-BG',
#  'https://www.glasistre.hr': 'glasistre',
#  'https://glavcom.ua': 'glavcom',
#  'https://www.ilmessaggero.it': 'ilmessaggero',
#  'https://www.lrt.lt': 'lrt-en',
#  'https://www.danas.rs': 'danas',
#  'https://global.foreignaffairs.co.nz': 'global-foreignaffairs',
#  'https://muscatinejournal.com': 'muscatinejournal',
#  'https://www.rmf24.pl': 'rmf24',
#  'https://www.smh.com.au': 'theherald-au',
#  'https://www.welt.de': 'Welt',
#  'https://g1.globo.com/jornal-nacional/noticia/2022/04/06/estados-unidos-anunciam-novas-sancoes-contra-instituicoes-financeiras-russas.ghtml': 'g1-globo',
#  'https://www.theguardian.com': 'observer',
#  'https://www.staradvertiser.com': 'HonululuAdvertiser',
#  'https://siouxcityjournal.com': 'siouxcityjournal',
#  'https://journalnow.com': 'journalnow',
#  'https://www.elfinanciero.com.mx': 'elfinanciero',
#  'https://newstes.ru': 'newstes',
#  'https://finance.rambler.ru': 'rns-online',
#  'https://www.archyde.com': 'archyde',
#  'https://www.belfasttelegraph.co.uk': 'belfasttelegraph',
#  'https://www.informador.mx': 'informador',
#  'https://www.pressandjournal.co.uk': 'pressandjournal',
#  'https://www.tvp.info': 'tvp',
#  'https://360tv.ru': '360tv',
#  'https://www.ntn24.com': 'ntn24',
#  'https://odocumento.com.br': 'odocumento',
#  'https://republicofmining.com': 'republicofmining',
#  'https://caijing.chinadaily.com.cn': 'chinadaily-zh',
#  'https://www.tvazteca.com': 'aztecanoticias',
#  'https://www.chesterstandard.co.uk': 'chesterfirst',
#  'https://nkeu.foreignaffairs.co.nz': 'newskitchen',
#  'https://www.rnd.de': 'rnd',
#  'https://www.asiaone.com': 'AsiaOne',
#  'https://news.bjx.com.cn': 'bjx',
#  'https://www.eluniversal.com.mx': 'eluniversal-MX',
#  'https://www.cbsnews.com': 'cbslocal',
#  'https://www.vozdeamerica.com': 'voanoticias',
#  'https://www.yourlocalguardian.co.uk': 'yourlocalguardian',
#  'https://1prime.ru': '1prime',
#  'https://www.eurasiareview.com': 'newsnow-co-uk',
#  'https://fremonttribune.com': 'fremonttribune',
#  'https://world.huanqiu.com': 'huanqiu',
#  'https://www.india.com': 'india',
#  'https://www.obserwatorfinansowy.pl': 'obserwatorfinansowy',
#  'https://wn.com': 'palestinewater',
#  'https://thesaxon.org': 'thesaxon',
#  'https://www.klamm.de': 'klamm',
#  'https://english.kyodonews.net': 'kyodonews',
#  'https://www.rbc.ua': 'rbc-ua',
#  'https://article.wn.com': 'wn',
#  'https://duma.bg': 'duma',
#  'https://www.bankingnews.gr': 'bankingnews',
#  'https://www.rappler.com': 'rappler',
#  'https://cn.reuters.com': 'reuters-cn',
#  'https://tsn.ua': 'coronavirus',
#  'https://www.dw.com': 'deutschewelle-tr',
#  'https://svpressa.ru': 'svpressa',
#  'https://www.yangtse.com': 'yangtse',
#  'http://world.qianlong.com': '21dnn',
#  'https://news.abs-cbn.com': 'abs-cbnnews',
#  'https://www.arabnews.com': 'arabnews',
#  'https://www.elespanol.com': 'navarra-elespanol',
#  'https://www.kauppalehti.fi': 'kauppalehti',
#  'https://www.naveenbharat.in': 'naveenbharat',
#  'https://www.ntdtv.com': 'ntdtv',
#  'https://www.thedailyherald.sx': 'thedailyherald-sx',
#  'https://wiadomosci.wp.pl': 'wp',
#  'https://www.163.com': '163',
#  'https://www.business-standard.com': 'business-standard',
#  'https://beta.rs': 'Beta-RS-sr',
#  'https://www.idahostatesman.com': 'idahostatesman',
#  'https://www.ilroma.net': 'ilroma',
#  'https://www.karar.com': 'karar',
#  'https://www.libertatea.ro': 'libertatea',
#  'https://www.salzgitter-zeitung.de': 'salzgitter-zeitung',
#  'https://www.sfgate.com': 'sfgate',
#  'https://visao.sapo.pt': 'visao',
#  'https://www.amerikiskhma.com': 'amerikiskhma',
#  'https://www.noticiasdenavarra.com': 'noticiasdenavarra',
#  'https://obzor.lt': 'obzor',
#  'https://www.parlamentnilisty.cz': 'parlamentnilisty',
#  'https://www.saarbruecker-zeitung.de': 'saarbruecker-zeitung',
#  'https://tribune.com.pk': 'tribune',
#  'https://www.unian.net': 'unian-en',
#  'https://www.capital.ro': 'capital-RO',
#  'https://www.finanzen100.de': 'finanzen100',
#  'https://www.finanznachrichten.de': 'finanznachrichten-en',
#  'https://www.gifhorner-rundschau.de': 'gifhorner-rundschau',
#  'https://novyny.online.ua': 'news-online-uk',
#  'https://www.onvista.de': 'onvista',
#  'https://www.peiner-nachrichten.de': 'peiner-nachrichten',
#  'https://time.mk': 'time-mk',
#  'https://www.europe1.fr': 'Europe1',
#  'https://www.haber24.com': 'haber24',
#  'https://www.infobae.com': 'infobae',
#  'https://jornaldebrasilia.com.br': 'jornaldebrasilia',
#  'https://www.kathimerini.com.cy': 'kathimerini-cy',
#  'https://www.maz-online.de': 'maerkischeallgemeine',
#  'http://www.agoramagazine.it': '247libero',
#  'https://247newsbulletin.com': '247newsbulletin',
#  'https://www.dnn.de': 'dnn-online',
#  'https://lacrossetribune.com': 'lacrossetribune',
#  'https://www.sapo.pt': 'sapo',
#  'https://www.streetinsider.com': 'streetinsider',
#  'https://www.thesouthafrican.com': 'thesouthafrican',
#  'https://www.vesti.rs': 'vesti-rs',
#  'https://openiazoch.zoznam.sk': 'zoznam',
#  'https://www.frankenpost.de': 'frankenpost',
#  'https://ghn.ge': 'ghn',
#  'https://www.haz.de': 'haz',
#  'https://news-24.fr': 'news-24',
#  'https://jp.reuters.com': 'reuters-jp',
#  'https://www.thueringer-allgemeine.de': 'thueringer-allgemeine',
#  'https://www.bta.bg': 'BulgariaTelegraph-bg',
#  'https://www.cumhuriyet.com.tr': 'cumhuriyet',
#  'https://www.noz.de': 'dk-online',
#  'https://www.forbes.com': 'forbes',
#  'https://www.kn-online.de': 'kn-online',
#  'https://missoulian.com': 'missoulian',
#  'https://www.publika.md': 'publika',
#  'https://www.rfi.fr': 'rfi-pt',
#  'https://www.startribune.com': 'startribune',
#  'https://www.thenationalherald.com': 'thenationalherald',
#  'https://www.euronews.rs': 'euronews-rs',
#  'https://gordonua.com': 'gordonua',
#  'https://korrespondent.net': 'korrespondent',
#  'https://www.lvz.de': 'lvz-online',
#  'https://www.plenglish.com': 'plenglish',
#  'https://trm.md': 'trm',
#  'https://www.tuko.co.ke': 'kenyamoja',
#  'https://ct24.ceskatelevize.cz': 'ct24',
#  'https://utroruse.com': 'utroruse',
#  'http://abidjantv.net': 'abidjantv',
#  'https://www.augsburger-allgemeine.de': 'augsburger-allgemeine',
#  'https://business.dir.bg': 'business-bg',
#  'https://www.debate.com.mx': 'debate',
#  'https://fergana.agency': 'fergananews',
#  'https://wiadomosci.gazeta.pl': 'gazeta-wiadomosci',
#  'https://www.iefimerida.gr': 'iefimerida',
#  'https://www.newsbeast.gr': 'newsbeast',
#  'https://www.nnn.de': 'nnn-de',
#  'https://www.protothema.gr': 'gazzetta-gr',
#  'https://www.svz.de': 'svz',
#  'https://ipsnoticias.net': 'ipsnoticias',
#  'https://www.islandpacket.com': 'islandpacket',
#  'https://levice.virtualne.sk': 'levice-virtualne',
#  'https://www.onalert.gr': 'onalert',
#  'https://www.telegraaf.nl': 'telegraaf',
#  'https://www.army-technology.com': 'defence-nridigital',
#  'https://www.giessener-allgemeine.de': 'alsfelder-allgemeine',
#  'https://www.businessinsider.com': 'businessinsider-en',
#  'https://www.click2houston.com': 'click2houston',
#  'https://www.elperiodico.com': 'elperiodico',
#  'https://moldova-suverana.md': 'moldova-suverana',
#  'https://sofokleous10.gr/category/paraskinio/': 'sofokleous10',
#  'https://noticieros.televisa.com': 'televisa',
#  'https://thenewsnigeria.com.ng': 'thenewsnigeria',
#  'https://www.watoday.com.au': 'watoday',
#  'https://www.infooggi.it': 'infooggi',
#  'https://www.kitco.com': 'kitco',
#  'https://www.lasprovincias.es': 'lasprovincias',
#  'https://nypost.com': 'nypost',
#  'https://radiogdansk.pl': 'radiogdansk',
#  'https://www.sofokleousin.gr': 'sofokleousin',
#  'https://www.tveuropa.pt': 'tveuropa',
#  'https://www.yorkpress.co.uk': 'yorkpress',
#  'https://www.iheartradio.ca': 'cfra',
#  'https://www.dailymail.co.uk': 'dailymail',
#  'https://deita.ru': 'deita',
#  'https://financialpost.com': 'financialpost',
#  'https://wiadomosci.onet.pl': 'onet-poznan',
#  'https://www.rnz.de': 'rnz',
#  'https://www.spglobal.com': '451research',
#  'https://politics.comments.ua/sub-category/foreign-policy': 'ua-comments',
#  'https://westernpeople.ie': 'westernpeople',
#  'https://www.postandcourier.com': 'aikenstandard',
#  'https://www.antena3.ro': 'antena3',
#  'https://newsdome.co.za': 'dailymaverick',
#  'https://www.euronews.com': 'euronews-en',
#  'https://www.fdd.org': 'fdd',
#  'https://www.franceinter.fr': 'franceinter',
#  'https://www.ghanaweb.com': 'ghanaweb',
#  'https://www.globsec.org': 'globsec',
#  'http://www.jordantimes.com': 'jordantimes',
#  'https://www.live5news.com': 'live5news',
#  'https://www.opovo.com.br': 'opovo',
#  'https://profitline.hu': 'profitline',
#  'https://www.nuevatribuna.es': 'nuevatribuna',
#  'https://www.romaniatv.net': 'romaniatv',
#  'https://www.shinmai.co.jp': 'shinmai',
#  'https://www.agroinform.hu': 'agroinform',
#  'https://www.fuldaerzeitung.de': 'fuldaerzeitung',
#  'https://www.rundschau.at': 'rundschau',
#  'https://www.slobodna-bosna.ba': 'slobodna-bosna',
#  'https://www.mirror.co.uk': 'themirror',
#  'https://vpoint.jp/author/vienna': 'vpoint',
#  'https://dailyjournal.net': 'dailyjournal',
#  'https://www.irishtimes.com': 'irishtimes',
#  'https://www.politico.eu': 'politico-eu',
#  'http://www.sana.sy': 'Sana-tr',
#  'https://www.wsoctv.com': 'wsoctv',
#  'https://alphapatras.gr': 'alphapatras',
#  'https://www.eldiariomontanes.es': 'eldiariomontanes',
#  'https://moldova.europalibera.org': 'europalibera',
#  'https://financialintelligence.ro': 'financialintelligence',
#  'https://www.franceculture.fr': 'franceculture',
#  'https://haqqin.az': 'haqqin',
#  'https://www.kentucky.com': 'kentucky',
#  'https://www.longbeachstar.com': 'longbeachstar',
#  'https://www.polandsun.com': 'polandsun',
#  'https://www.thejournal.ie': 'thejournal',
#  'https://english.almayadeen.net': 'almayadeen-en',
#  'https://expresso.pt': 'expresso',
#  'https://qubit.hu': 'qubit',
#  'https://inbusinessnews.reporter.com.cy': 'inbusinessnews',
#  'https://www.insider.gr': 'insider',
#  'https://pia.ge': 'pia',
#  'https://www.ta3.com': 'ta3',
#  'https://ziare.com': 'ziare',
#  'https://www.chinadailyhk.com': 'chinadailyhk',
#  'https://guardiao-ao.com': 'guardiao-ao',
#  'https://menafn.com': 'menafn',
#  'https://www.polskieradio.pl': 'polskieradio',
#  'https://www.theregister.com': 'register',
#  'https://www.stuttgarter-nachrichten.de': 'stuttgarter-nachrichten',
#  'https://timgate.it:443/news/italia/prime-pagine-giornali-titoli-04-04-22.vum': 'timgate',
#  'https://notizie.tiscali.it': 'tiscali-it',
#  'https://www.tornosnews.gr': 'tornosnews',
#  'https://www.aljazeera.com': 'aljazeera-en',
#  'https://www.alphafreepress.gr': 'alphafreepress',
#  'https://www.eurointegration.com.ua': 'eurointegration',
#  'https://serwisy.gazetaprawna.pl': 'gazetaprawna',
#  'https://www.liberal.gr': 'liberal',
#  'https://www.nationaltribune.com.au': 'nationaltribune',
#  'https://noticierouniversal.com': 'noticierouniversal',
#  'http://www.primapress.it': 'primapress',
#  'https://spotmedia.ro': 'spotmedia',
#  'https://www.tagesschau.de': 'wdr',
#  'https://www.theolympian.com': 'theolympian',
#  'https://www.trend.az': 'trendnews-az-ru',
#  'https://www.actionnewsjax.com': 'actionnewsjax',
#  'https://www.dagbladet.no': 'dagbladet',
#  'https://www.energy-supply.dk': 'energy-supply',
#  'https://www.news24.com': 'news24',
#  'https://www.ot.gr': 'ot',
#  'https://www.blic.rs': 'blic',
#  'https://www.govinfosecurity.com': 'govinfosecurity',
#  'https://www.klix.ba': 'klix',
#  'https://www.ladepeche.fr': 'ladepeche',
#  'https://lenta.ru': 'lenta',
#  'https://www.b92.net': 'b92net_en',
#  'https://gouvernement.lu': 'gouvernement-LU',
#  'https://kloop.kg': 'kloop',
#  'https://www.polesine24.it': 'lavoce-nuova',
#  'https://lequotidien.lu': 'quotidien-lu',
#  'https://www.thepresident.gr': 'thepresident',
#  'https://www.euractiv.com': 'euractiv-en',
#  'https://www.huaral.pe/opinion-dennis-falvy-olaf-scholz-el-pitufo-inteligente/2022/': 'huaral',
#  'https://www.in.gr': 'in-gr',
#  'https://www.la.lv': 'la',
#  'https://lifedon.com.ua': 'lifedon',
#  'https://www.lindependant.fr': 'lindependant',
#  'https://www.moldpres.md': 'moldpres-ro',
#  'https://www.moneycontrol.com': 'moneycontrol',
#  'https://www.stern.de': 'stern',
#  'https://tvxs.gr': 'tvxs',
#  'https://www.9colonne.it': '9colonne-it',
#  'https://www.bfmtv.com': 'bfmtv',
#  'https://www.deaandeelhouder.nl': 'deaandeelhouder',
#  'https://digitpatrox.com': 'digitpatrox',
#  'https://www.channelnewsasia.com': 'channelnewsasia',
#  'https://www.delfi.lv': 'delfi',
#  'https://formiche.net': 'formiche',
#  'https://apnews.com': 'apnews',
#  'https://www.kouvolansanomat.fi': 'kouvolansanomat',
#  'https://www.lrytas.lt': 'lrytas',
#  'https://www.sss.fi': 'sss',
#  'https://www.ess.fi': 'ess',
#  'https://www.karjalainen.fi': 'karjalainen',
#  'https://ria.ru': 'rian',
#  'https://www.tvnet.lv': 'tvnet',
#  'http://salamnews.org': 'salamnews',
#  'https://www.taxydromos.gr': 'taxydromos',
#  'https://1news.az': '1news',
#  'https://www.lidovky.cz': 'lidovky',
#  'https://www.g4media.ro': 'g4media-EN',
#  'https://www.lavozdigital.es': 'lavozdigital',
#  'https://parstoday.com': 'parstoday',
#  'https://www.alphatv.gr': 'AlphaTV',
#  'https://euractiv.cz': 'euractiv-cz',
#  'https://hvg.hu': 'hvg',
#  'https://www.novosti.rs': 'novosti-rs',
#  'https://politexpert.net': 'poltexpert',
#  'https://seenews.com': 'seenews',
#  'https://www.themoscowtimes.com': 'themoscowtimes',
#  'https://www.express.co.uk': 'express',
#  'https://www.efsyn.gr': 'efsyn',
#  'https://www.francetvinfo.fr': 'la1ere',
#  'https://www.milanofinanza.it': 'milanofinanza',
#  'https://news.myseldon.com': 'myseldon',
#  'https://regnum.ru': 'regnum',
#  'https://riafan.ru': 'riafan',
#  'https://www.valigiablu.it': 'valigiablu',
#  'https://www.yenisafak.com': 'yenisafak-en',
#  'https://www.ansa.it': 'ansa-Europa',
#  'https://charter97.org': 'charter97',
#  'https://www.ecomy.it': 'ecomy-it',
#  'https://magyarnemzet.hu': 'mno',
#  'https://www.money.it': 'money-it',
#  'https://www.ptisidiastima.com': 'ptisidiastima',
#  'https://rp-online.de': 'ngz-online',
#  'https://ground.news': 'ground-news',
#  'https://wydarzenia.interia.pl': 'interia',
#  'https://newizv.ru': 'newizv',
#  'https://rus.postimees.ee': 'rus-postimees',
#  'https://fakti.bg': 'fakti',
#  'http://www.finmarket.ru': 'finmarket',
#  'https://www.huffingtonpost.it': 'huffingtonpost-Italia',
#  'https://kurier.at': 'kurier',
#  'https://elobrero.es': 'elobrero',
#  'https://it.marketscreener.com': 'marketscreener',
#  'https://en.portnews.ru': 'portnews',
#  'https://www.teraz.sk': 'teraz',
#  'https://delo.ua': 'delo-ua',
#  'https://tribune.net.ph': 'tribuneonline',
#  'https://africanmanager.com': 'africanmanager',
#  'https://www.independent.ie': 'iua.ie-website',
#  'https://internationalwealth.info': 'internationalwealth',
#  'https://www.lasicilia.it': 'lasicilia',
#  'https://www.rheinpfalz.de': 'rheinpfalz',
#  'https://www.rosbalt.ru': 'rosbalt',
#  'https://www.slobodenpecat.mk': 'slobodenpecat-en',
#  'https://www.aa.com.tr': 'aa',
#  'https://www.banker.bg': 'banker',
#  'https://dariknews.bg': 'darik',
#  'https://news.dialog.ua': 'dialog-ua',
#  'https://www.eldemocrata.cl': 'eldemocrata',
#  'https://energy.economictimes.indiatimes.com': 'energy-economictimes',
#  'https://www.fr.de': 'fr-de',
#  'https://www.kreiszeitung.de': 'kreiszeitung',
#  'https://bnn.de': 'bnn',
#  'https://www.lemonde.fr': 'LeMonde-en',
#  'https://www.sb.by': 'sb',
#  'https://www.bbc.com': 'bbc-vietnam',
#  'https://www.businesstelegraph.co.uk': 'businesstelegraph',
#  'https://www.francebleu.fr': 'francebleu',
#  'https://gtmedia.ge': 'gtmedia',
#  'https://www.ilgiornale.it': 'ilgiornale',
#  'https://www.interpressnews.ge': 'interpressnews',
#  'https://www.larazon.es': 'larazon-es',
#  'https://www.leggo.it': 'leggo',
#  'https://www.milenio.com': 'milenio',
#  'https://www.tanea.gr': 'tanea',
#  'https://www.bristolpost.co.uk': 'bristolpost',
#  'https://eurokerdos.cyprustimes.com': 'eurokerdos-english',
#  'https://www.interfax.ru': 'interfax-ru',
#  'https://www.krqe.com': 'krqe',
#  'https://www.lecodelsud.it': 'lecodelsud',
#  'https://www.mopo.de': 'mopo',
#  'https://www.elobservador.com.uy': 'elobservador',
#  'https://www.for.kg': 'for-kg',
#  'https://profit.bg': 'profit-bg',
#  'https://www.sandiegouniontribune.com': 'sandiegouniontribune',
#  'https://ura.news': 'ura',
#  'https://www.burgosconecta.es': 'burgosconecta',
#  'https://www.jurnal.md': 'jurnal',
#  'https://www.kommersant.ru': 'kommersant',
#  'https://laragione.eu': 'laragione',
#  'https://libertas.mk': 'libertas',
#  'https://www.northernirelandnews.com': 'northernirelandnews',
#  'https://www.noticiasaominuto.com': 'noticiasaominuto',
#  'https://primetime.ge': 'primetime',
#  'https://www.startmag.it': 'startmag',
#  'https://www.thedailystar.net': 'thedailystarBD',
#  'https://thetimeshub.in': 'thetimeshub',
#  'https://www.thestar.com': 'TorontoStar',
#  'https://www.budapesttimes.hu': 'budapesttimes',
#  'https://rus.delfi.lv': 'delfi-rus',
#  'https://www.deutschlandfunk.de': 'deutschlandfunk',
#  'https://eleftherostypos.gr': 'eleftherostypos',
#  'https://www.foxnews.com': 'foxnews',
#  'https://www.genteditalia.org': 'genteditalia',
#  'https://www.informazione.it': 'informazione',
#  'https://linkezeitung.de': 'linkezeitung',
#  'https://www.msn.com/el-gr/news/techandscience/m%CE%B1%CF%8D%CF%81%CE%B5%CF%82-%CF%84%CF%81%CF%8D%CF%80%CE%B5%CF%82-%CE%AC%CF%83%CF%84%CF%81%CE%B1-%CE%BD%CE%B5%CF%84%CF%81%CE%BF%CE%BD%CE%AF%CE%BF%CF%85-%CE%BA%CE%B1%CE%B9-%CE%B3%CE%B1%CE%BB%CE%B1%CE%BE%CE%AF%CE%B5%CF%82-%CF%80%CE%B1%CF%81%CE%AC%CF%80%CE%BB%CE%B5%CF%85%CF%81%CE%B5%CF%82-%CE%B1%CF%80%CF%8E%CE%BB%CE%B5%CE%B9%CE%B5%CF%82-%CF%84%CE%B7%CF%82-%CE%B5%CE%B9%CF%83%CE%B2%CE%BF%CE%BB%CE%AE%CF%82-%CF%83%CF%84%CE%B7%CE%BD-%CE%BF%CF%85%CE%BA%CF%81%CE%B1%CE%BD%CE%AF%CE%B1/ar-AAUDv9r?li=BBqxCu2': 'msn-gr',
#  'https://www.olbianotizie.it': 'olbianotizie',
#  'https://www.cbs17.com': 'cbs17',
#  'https://elfarodeceuta.es': 'elfarodeceuta',
#  'https://forsal.pl': 'forsal',
#  'https://www.imerisia.gr': 'imerisia',
#  'https://bne.eu': 'intellinews',
#  'https://www.latestly.com': 'latestly',
#  'https://www.latribune.fr': 'latribune',
#  'https://www.malaymail.com': 'themalaymailonline',
#  'https://newpost.gr': 'newpost',
#  'https://www.news247.gr': 'news247',
#  'https://www.rtvslo.si': 'rtvslo',
#  'https://www.szon.hu': 'szabolcs',
#  'http://www.adaderana.lk': 'adaderana',
#  'https://www.albawaba.com': 'albawaba-ar',
#  'https://www.tagesspiegel.de': 'Tagespiegel',
#  'https://www.gazeta.ru': 'gazeta-ru',
#  'https://www.corriere.it': 'corriere',
#  'https://www.nakanune.ru': 'nakanune',
#  'http://www.news.cn': 'cn-news',
#  'https://www.mynews13.com': 'mynews13',
#  'https://www.wowktv.com': 'wowktv',
#  'https://actmedia.eu': 'actmedia-eu',
#  'https://www.adnkronos.com': 'adnkronos',
#  'http://avesta.tj': 'avesta',
#  'https://www.vozpopuli.com': 'vozpopuli',
#  'https://www.euro2day.gr': 'euro2day',
#  'https://net.hr': 'net',
#  'https://www.theepochtimes.com': 'theepochtimes',
#  'https://hromadske.ua': 'hromadske-ua',
#  'https://www.mondopalermo.it': 'mondopalermo',
#  'https://nation.com.pk': 'nation',
#  'http://www.virginislandsdailynews.com': 'virginislandsdailynews',
#  'https://www.secoloditalia.it': 'secoloditalia',
#  'https://nezavisen.mk': 'nezavisen',
#  'https://www.ripartelitalia.it': 'ripartelitalia',
#  'https://www.t-online.de': 't-online',
#  'https://asiatimes.com': 'asiatimes',
#  'https://www.barrons.com': 'barrons',
#  'https://news.bjd.com.cn': 'bjdcom',
#  'https://generationsnouvelles.net': 'generationsnouvelles',
#  'https://money.udn.com': 'money-udn',
#  'https://naszdziennik.pl': 'naszdziennik',
#  'https://www.hetek.hu': 'hetek',
#  'https://www.krone.at': 'krone',
#  'https://www.kuwaittimes.com': 'kuwaittimes',
#  'https://www.pi-news.net': 'pi-news',
#  'https://news.sina.cn': 'sinacom',
#  'https://www.varesenews.it': 'varesenews',
#  'https://www.hindustantimes.com': 'HindustanTimes',
#  'https://www.lastampa.it': 'lastampa',
#  'https://plus7dni.pluska.sk': 'pluska',
#  'https://www.aninews.in': 'aninews',
#  'https://biznesalert.pl': 'biznesalert',
#  'https://www.gmanetwork.com': 'gmanews',
#  'https://www.klubradio.hu': 'klubradio',
#  'https://www.oglioponews.it': 'oglioponews',
#  'https://www.epravda.com.ua': 'pravda-ua',
#  'https://biznes.trojmiasto.pl': 'trojmiasto',
#  'https://www.gazzettadimodena.it': 'gazzettadimodena',
#  'https://clubz.bg': 'clubz-bg',
#  'https://www.cna.com.tw': 'cnataiwan',
#  'https://www.dnes.bg': 'dnes',
#  'https://www.thesundaily.my': 'thesundaily',
#  'https://echo24.cz': 'echo24',
#  'https://www.vikendi.net': 'vikendi',
#  'https://it.geosnews.com': 'it-geosnews',
#  'https://www.24plovdiv.bg': '24plovdiv',
#  'https://www.24chasa.bg': '24chasa',
#  'https://www.cityam.com': 'cityam',
#  'https://www.agerpres.ro': 'agerpres-en',
#  'http://finanza.tgcom24.mediaset.it': 'mediaset',
#  'https://udn.com': 'udn',
#  'https://ufatime.ru': 'ufatime',
#  'https://www.leta.lv': 'leta.lv-website',
#  'https://noveslovo.sk': 'noveslovo.sk',
#  'https://24tv.ua': '24tv',
#  'https://www.civilhetes.net': 'civilhetes',
#  'https://dgap.org': 'dgap',
#  'https://www.lapresse.ca': 'lapresse-CA',
#  'https://www.mittelbayerische.de': 'mittelbayerische',
#  'https://www.news4jax.com': 'news4jax',
#  'https://politis.com.cy': 'politis-news',
#  'https://worldakkam.com': 'worldakkam',
#  'https://www.fresnobee.com': 'fresnobee',
#  'https://www.ledger-enquirer.com': 'ledger-enquirer',
#  'https://www.lessentiel.lu': 'lessentiel-lu-lb',
#  'https://newsland.com': 'newsland',
#  'https://wiadomosci.radiozet.pl': 'radiozet',
#  'https://www.brecorder.com': 'brecorder',
#  'https://buffalonews.com': 'buffalonews',
#  'https://carnegieeurope.eu': 'carnegie-us-en',
#  'https://www.hirstart.hu': 'hirstart',
#  'https://www.newsobserver.com': 'newsobserver',
#  'https://www.021.rs': '021-rs',
#  'http://abc.az': 'abc-az',
#  'https://eu-recycling.com': 'eu-recycling',
#  'https://www.ceskenoviny.cz': 'ceskenoviny',
#  'https://www.money.ro': 'money-ro',
#  'https://www.shum.bg': 'shum',
#  'https://centralasia.media': 'ca-news-ru',
#  'https://english.alarabiya.net': 'alarabiya-en',
#  'https://elperiodicodelaenergia.com': 'elperiodicodelaenergia',
#  'https://www.sunherald.com': 'sunherald',
#  'https://www.wftv.com': 'wftv',
#  'https://www.breakingnews.ie': 'breakingnews-ie',
#  'https://www.tks.ru': 'tks',
#  'https://www.wral.com': 'wral',
#  'https://www.expert.bg': 'expert-bg',
#  'https://faktor.bg': 'faktor',
#  'https://www.president.gov.ua': 'president-gov-ua',
#  'https://wyborcza.pl': 'poznan',
#  'https://eldeber.com.bo': 'eldeber',
#  'https://www.lsm.lv': 'lsm',
#  'https://www.thecitizen.co.tz': 'theCitizen',
#  'https://www.diariovasco.com': 'DiarioVasco',
#  'https://www.eunews.it': 'eunews',
#  'https://www.friendsofeurope.org': 'friendsofeurope',
#  'http://www.idexonline.com': 'idexonline',
#  'https://www.independent.co.uk': 'independent-UK',
#  'https://mixnews.lv': 'mixnews',
#  'https://www.thenewstribune.com': 'thenewstribune',
#  'https://www.wiwo.de': 'wirtschaftswoche',
#  'https://www.bemparana.com.br': 'bemparana',
#  'https://www.bnd.com': 'bnd',
#  'https://www.clickondetroit.com': 'clickondetroit',
#  'https://www.financialmirror.com': 'FinancialMirror',
#  'https://www.newstatesman.com': 'newstatesman',
#  'https://notesfrompoland.com': 'notesfrompoland',
#  'https://www.bgonair.bg': 'bgonair',
#  'https://www.boursier.com': 'boursier-fr',
#  'https://www.ideal.es': 'ideal',
#  'https://zn.ua': 'dt-ua',
#  'http://world.people.com.cn': 'peoplecom',
#  'https://www.standard.co.uk': 'standard',
#  'https://www.bankier.pl': 'bankier',
#  'https://www.livekuban.ru': 'livekuban',
#  'https://asia.nikkei.com': 'nikkei-en',
#  'https://ubr.ua': 'ubr-ua',
#  'https://www.index.hr': 'index-hr',
#  'https://lider.mk': 'lider',
#  'https://www.timer.ge': 'timer',
#  'https://www.bns.lt': 'BalticNewsService',
#  'https://www.capital.gr': 'capital-GR',
#  'https://www.mskagency.ru': 'mskagency',
#  'http://www.ap22.ru': 'ap22',
#  'https://finance.bigmir.net': 'bigmir',
#  'https://www.bloombergtv.bg': 'bloombergtv',
#  'https://www.mondaq.com': 'mondaq',
#  'https://www.newsit.gr': 'newsit',
#  'https://wacotrib.com': 'wacotrib',
#  'https://e24.no': 'bt-no',
#  'https://www.dnes24.sk': 'dnes24',
#  'https://gospodarka.dziennik.pl': 'dziennik',
#  'https://www.elconfidencialdigital.com': 'elconfidencialdigital',
#  'https://www.eleconomista.es': 'ecodiario',
#  'https://vsluh.ru': 'vsluh',
#  'https://a1on.mk': 'a1on',
#  'https://www.bild.de': 'bild',
#  'https://www.echoroukonline.com': 'ech-chorouk-fr',
#  'https://punchng.com': 'punchng',
#  'https://www.dubrovniknet.hr': 'dubrovniknet',
#  'https://esgdata.it': 'esgdata',
#  'https://informpskov.ru': 'informpskov',
#  'https://www.novinky.cz': 'novinky',
#  'https://observador.pt': 'observador',
#  'https://www.offsite.com.cy': 'offsite',
#  'https://www.pambianconews.com': 'pambianconews',
#  'https://rtcg.me': 'rtcg',
#  'https://www.theglobeandmail.com': 'theglobeandmail',
#  'https://www.aftenposten.no': 'aftenposten',
#  'https://www.bizcommunity.com': 'bizcommunity',
#  'https://borsen.dk': 'borsen',
#  'https://www.cas.sk': 'cas',
#  'https://energiaoltre.it': 'energiaoltre',
#  'https://www.fanpage.it': 'fanpage',
#  'https://gazette.com': 'gazette',
#  'https://www.minyu-net.com': 'minyu-net',
#  'https://www.pravda.com.ua': 'pravda-ua-eng',
#  'https://www.thenationalnews.com': 'thenational',
#  'https://www.diarioabierto.es': 'diarioabierto',
#  'https://www.federalna.ba': 'federalna-ba',
#  'https://timesofindia.indiatimes.com/world/rest-of-world/russia-steps-up-assault-on-east-ukraine-putin-threatens-countries-that-intervene/articleshow/91148574.cms': 'timesofindia',
#  'https://www.zougla.gr': 'zougla',
#  'https://24.mk': '24mk',
#  'https://cursdeguvernare.ro': 'cursdeguvernare',
#  'https://daily.mk': 'daily-mk',
#  'http://www.xinhuanet.com': 'xinhuanet',
#  'http://www.apn.ru': 'apn',
#  'https://news.mail.ru': 'news-mail-ru',
#  'https://www.pcnen.com': 'pcnen',
#  'https://www.telam.com.ar': 'telam',
#  'https://www.telegraph.co.uk': 'telegraph',
#  'https://www.handelsblatt.com': 'Handelsblatt',
#  'https://timesofmalta.com': 'timesofmalta',
#  'https://www.20minutos.es': '20minutos',
#  'https://www.24ur.com': '24ur',
#  'https://www.verkkouutiset.fi': 'verkkouutiset',
#  'https://www.wolfsburger-nachrichten.de': 'wolfsburger-nachrichten',
#  'https://www.energia.gr': 'energia',
#  'https://www.fontanka.ru': 'fontanka',
#  'https://www.reggio2000.it': 'reggio2000',
#  'https://www.tgcom24.mediaset.it': 'tgcom',
#  'https://www.helmstedter-nachrichten.de': 'helmstedter-nachrichten',
#  'http://www.europesun.com': 'europesun',
#  'https://www.lereporter.ma': 'lereporter-ma',
#  'https://rueconomics.ru': 'rueconomics',
#  'https://www.rtl.de': 'rtl',
#  'https://www.sardiniapost.it': 'sardiniapost',
#  'https://www.whig.com': 'whig',
#  'https://www.ilfattonisseno.it': 'ilfattonisseno',
#  'https://www.italpress.com': 'italpress',
#  'https://www.protagon.gr': 'protagon',
#  'https://www.unian.ua': 'unian',
#  'https://www.unravelmalta.com': 'unravelmalta',
#  'https://www.sankei.com': 'sankei',
#  'http://www.solinger-tageblatt.de': 'solinger-tageblatt',
#  'https://www.pnp.de': 'pnp',
#  'https://www.elimpulso.com': 'elimpulso',
#  'https://www.terra.com.br': 'noticias-terra-br',
#  'https://www.facenews.ua/news/2022/522868/': 'facenews',
#  'https://www.lacnews24.it': 'lacnews24',
#  'https://valenciaplaza.com': 'valenciaplaza',
#  'https://www.ildenaro.it': 'ildenaro',
#  'http://www.rga.de': 'rga-online',
#  'https://www.arkansasonline.com': 'arkansasonline',
#  'https://dnesplus.bg': 'dnesplus',
#  'https://www.braunschweiger-zeitung.de': 'braunschweiger-zeitung',
#  'https://www.grandangoloagrigento.it': 'grandangoloagrigento',
#  'https://www.promptmedia.ro': 'promptmedia',
#  'https://www.rts.rs/page/stories/ci/story/3395/rat-u-ukrajini/4733700/ukrajina-rusija-rat-sad-sankcije.html': 'rts',
#  'https://zinas.tv3.lv': 'tv3',
#  'https://taz.de': 'taz',
#  'https://vijesti.ba': 'vijesti-ba',
#  'https://33live.ru': '33live',
#  'https://accentnews.ge': 'accent',
#  'https://www.dailyecho.co.uk': 'dailyecho',
#  'https://www.e15.cz': 'e15',
#  'https://eco.sapo.pt': 'eco',
#  'https://www.euractiv.fr': 'euractiv-fr',
#  'https://inews.co.uk': 'inews-co-uk',
#  'https://japantoday.com': 'japantoday',
#  'https://www.msn.com': 'msn-fr',
#  'https://tn.nova.cz': 'tn',
#  'http://www.shikoku-np.co.jp': 'shikoku-np',
#  'https://www.telegraf.rs': 'telegraf',
#  'https://www.ticinonews.ch': 'ticinonews',
#  'https://www.vg.hu': 'vg-online',
#  'https://www.apollo.lv': 'apollo',
#  'https://www.borsainside.com': 'borsainside',
#  'https://www.elnacional.cat': 'elnacional-catala',
#  'https://www.europa-nu.nl': 'europa-nu',
#  'https://www.impartialreporter.com': 'impartialreporter',
#  'https://www.interris.it': 'interris',
#  'https://www.irishexaminer.com': 'irishexaminer',
#  'https://www.mesagerul.ro': 'mesagerul',
#  'https://www.republicain-lorrain.fr': 'republicain-lorrain',
#  'https://www.tatar-inform.ru': 'tatar-inform',
#  'https://www.az-online.de': 'az-online',
#  'https://www.estrepublicain.fr': 'estrepublicain',
#  'https://evz.ro': 'evz',
#  'https://www.magyarszo.rs': 'magyarszo',
#  'https://www.panorama.am': 'panorama-am-en',
#  'https://www.rsi.ch': 'rsi-ch',
#  'https://trud.bg': 'trud-BG',
#  'https://www.star.com.tr': 'stargazete',
#  'https://news.err.ee': 'err-en',
#  'https://www.extremetech.com': 'extremetech',
#  'https://www.ouest-france.fr': 'OuestFrance',
#  'https://www.spectator.co.uk': 'thespectator',
#  'https://bnn-news.com': 'BalticNewsNetwork',
#  'https://www.elnortedecastilla.es': 'elnortedecastilla',
#  'https://pealinn.ee': 'pealinn',
#  'https://europe.vivianedebeaufort.fr': 'vivianedebeaufort',
#  'https://www.diarioextra.com': 'diario-extra',
#  'https://www.gp.se': 'goteborgpost',
#  'https://omegalive.com.cy': 'omegalive',
#  'https://profile.ru': 'profile',
#  'https://tvn24.pl': 'tvn24',
#  'https://espreso.tv': 'espreso',
#  'https://www.kp.ru': 'kp',
#  'https://www.politika.rs': 'politika',
#  'http://www.resonancedaily.com': 'resonancedaily',
#  'https://tvi.iol.pt': 'tvi',
#  'https://sg.news.yahoo.com': 'yahoo-sg',
#  'https://www.fnp.de': 'fnp',
#  'https://www.lainformacion.com': 'lainformacion',
#  'http://www.tvc.ru': 'tvc',
#  'https://www.webnoviny.sk': 'webnoviny',
#  'https://www.dn.se': 'dn-se',
#  'https://www.huffingtonpost.fr': 'huffingtonpost-fr-fr',
#  'https://www.investor.bg': 'investor',
#  'https://www.otz.de': 'otz',
#  'https://southfront.org': 'southfront',
#  'https://english.aawsat.com': 'aawsat',
#  'https://factcheck.kg': 'factcheck-kg',
#  'https://www.globalsecurity.org': 'globalsecurity',
#  'http://marketnews.gr': 'marketnews',
#  'https://www.wnp.pl': 'wnp',
#  'https://www.alphanews.live': 'alphanews',
#  'https://www.farsnews.ir': 'parseek',
#  'https://www.sigmalive.com': 'simerini',
#  'https://www.scotsman.com': 'TheScotsman',
#  'https://www.tivi.fi': 'tietoviikko',
#  'https://www.15min.lt': '15min-en',
#  'https://samacharcentral.com': 'samacharcentral',
#  'https://www.metrolibre.com': 'metrolibre',
#  'https://thewall.fyi': 'thewall',
#  'https://www.ilfattoquotidiano.it': 'ilfattoquotidiano',
#  'https://www.efeagro.com': 'efeagro',
#  'https://www.nouvelles-du-monde.com': 'nouvelles-du-monde',
#  'http://malijet.com': 'malijet',
#  'https://www.themandarin.com.au': 'themandarin',
#  'https://www.20min.ch': '20min',
#  'https://www.larioja.com': 'larioja',
#  'https://es.noticias.yahoo.com': 'es-noticias',
#  'https://www.o2.pl': 'o2',
#  'https://www.ensonhaber.com': 'ensonhaber',
#  'https://expressodasilhas.cv': 'expressodasilhas',
#  'https://www.is.fi': 'digitoday',
#  'https://jornaleconomico.pt': 'jornaleconomico',
#  'https://www.lapoliticaonline.com': 'lapoliticaonline',
#  'https://www.perfil.com': 'perfil',
#  'https://elsiglo.com.ve': 'elsiglo',
#  'https://thehill.com': 'thehill',
#  'https://www.morgenpost.de': 'BerlinMorgenpost',
#  'https://herd-und-hof.de': 'herd-und-hof',
#  'https://www.record.pt': 'record',
#  'https://kelo.com': 'kelo',
#  'https://www.notizieglobali.it': 'notizieglobali',
#  'https://playtech.ro': 'playtech',
#  'https://emisorasunidas.com': 'emisorasunidas',
#  'https://www.rp.pl': 'rzeczpospolita',
#  'https://www.focus.de': 'focus',
#  'https://www.abendblatt.de': 'AbendBlatt',
#  'https://eju.tv': 'eju',
#  'https://ekstrabladet.dk': 'ekstrabladet',
#  'https://www.waz.de': 'waz',
#  'https://www.wr.de': 'wr',
#  'https://www.efe.com': 'efe',
#  'https://www.hoy.es': 'HoyDigital',
#  'https://www.laverdad.es': 'laverdad',
#  'https://www.kathimerini.gr': 'kathimerini',
#  'https://sport.err.ee': 'err',
#  'https://www.wp.de': 'wp-de',
#  'https://todayheadline.co': 'todayheadline',
#  'https://www.elpais.cr': 'elpais-cr',
#  'https://klaipeda.diena.lt': 'klaipeda',
#  'https://www.lapatilla.com': 'lapatilla',
#  'https://elmercurio.com.mx': 'diarioelmercurio',
#  'https://www.businesspost.ie/author/businesspostteam': 'businesspost-ie',
#  'https://www.spokesman.com': 'spokesman',
#  'https://www.bz-berlin.de': 'bz-berlin',
#  'https://www.mister-x.it': 'mister-x',
#  'https://www.mondialisation.ca': 'mondialisation',
#  'https://globalnews.ca': 'globalnews',
#  'https://www.greatitalianfoodtrade.it': 'greatitalianfoodtrade',
#  'https://www.bloombergquint.com': 'bloombergquint',
#  'https://d1softballnews.com': 'd1softballnews',
#  'https://diariocorreo.pe': 'diariocorreo',
#  'https://economictimes.indiatimes.com/news/international/business/economic-ties-among-nations-spur-peace-or-do-they/articleshow/89997288.cms': 'economictimes',
#  'https://de.euronews.com': 'euronews-de',
#  'https://extra.globo.com': 'extra',
#  'https://www.finanzaonline.com': 'finanzaonline',
#  'https://printveela.com': 'printveela',
#  'https://www.azomining.com': 'azomining',
#  'https://comunidadeculturaearte.com': 'comunidadeculturaearte',
#  'https://www.dailybreeze.com': 'dailybreeze',
#  'https://www.eltelegrafo.com.ec': 'telegrafo',
#  'https://world.gmw.cn': 'gmw',
#  'https://www.jornaldenegocios.pt': 'jornaldenegocios',
#  'https://mainichi.jp': 'mainichi',
#  'https://www.mining.com': 'mining',
#  'http://www.tiempo.com.mx': 'tiempo-mx',
#  'https://www.zdnet.com': 'zdnet-BE',
#  'https://live.vodafone.de': 'arcor',
#  'https://www.cnnturk.com': 'cnnturk',
#  'https://www.gazetadopovo.com.br': 'gazetadopovo',
#  'https://imedinews.ge': 'imedi',
#  'https://www.nbcnewyork.com': 'nbcnewyork',
#  'https://stirileprotv.ro': 'stirileprotv',
#  'https://www.svebio.se': 'svebio',
#  'https://www.agriculture.com': 'agriculture-successful-farming',
#  'https://www.challenges.fr': 'challenges',
#  'https://www.tv3.lt': 'balsas',
#  'https://www.nouvelobs.com': 'nouvelobs',
#  'https://www.pagina12.com.ar': 'pagina12',
#  'https://www.naftemporiki.gr': 'naftemporiki',
#  'https://www.corsematin.com': 'corsematin',
#  'https://www.lanazione.it': 'LaNazione',
#  'https://dailytimes.com.pk': 'dailytimesPK',
#  'https://24.hu': 'fn',
#  'https://www.lexpress.fr': 'lexpansion-votreargent',
#  'https://www.pagenews.gr': 'pagenews',
#  'https://www.tendanceouest.com': 'tendanceouest',
#  'https://www.lagaceta.com.ar': 'lagaceta',
#  'https://castellonplaza.com': 'castellonplaza',
#  'http://news.lnd.com.cn': 'lnd',
#  'https://spacepolicyonline.com': 'spacepolicyonline',
#  'https://www.lamanchelibre.fr': 'lamanchelibre',
#  'https://www.thehindu.com/news/international/russia-ukraine-crisis-live-updatesjuly-16-2022/article65646625.ece': 'thehindu',
#  'https://www.bolsamania.com': 'bolsamania',
#  'http://en.people.cn': 'peopledaily',
#  'https://www.thestandard.com.hk': 'thestandard-hk',
#  'https://banksnews.gr': 'banksnews',
#  'https://www.letelegramme.fr': 'TelegrammeDeBrest',
#  'https://information.tv5monde.com': 'tv5',
#  'https://alicanteplaza.es': 'alicanteplaza',
#  'https://www.err.ee': 'vikerraadio',
#  'https://iz.ru': 'izvestia-ru',
#  'http://www.srilankaguardian.org': 'srilankaguardian',
#  'https://lepetitjournal.com': 'lepetitjournal',
#  'https://m.koreatimes.co.kr': 'koreatimes',
#  'https://allkharkov.ua': 'all-kharkov',
#  'https://telegraf.com.ua': 'telegraf-ua',
#  'https://irkutsk.bezformata.com': 'irkutsk-bezformata',
#  'http://apia-virtual.com': 'apiavirtual',
#  'https://nv.ua': 'nv',
#  'https://www.rtl.be': 'rtl-BE',
#  'https://www.cretalive.gr': 'cretalive',
#  'https://vat.pravda.sk': 'vat.pravda.sk',
#  'http://www.lemauricien.com': 'lemauricien',
#  'https://bdnews24.com': 'bdnews24',
#  'https://www.notretemps.com': 'notretemps',
#  'https://www.courrierinternational.com': 'courrierinternational',
#  'https://www.finanzas.com': 'finanzas',
#  'https://polskieradio24.pl': 'polskieradio24',
#  'https://timpul.md': 'timpul',
#  'https://www.asahi.com': 'ajw',
#  'https://www.maliweb.net': 'maliweb',
#  'https://www.radioradicale.it': 'radioradicale',
#  'https://www.straitstimes.com': 'straitstimesSG',
#  'https://www.cotidianul.ro': 'cotidianul',
#  'https://www.deia.eus': 'deia-eus',
#  'https://www.ilmattino.it': 'ilmattino',
#  'https://vz.ru': 'vz',
#  'https://www.hotnews.ro': 'hotnews-en',
#  'https://tv.cctv.com': 'cctv',
#  'https://www.bullfrag.com': 'bullfrag',
#  'https://www.taurillon.org': 'taurillon-de',
#  'https://www.ilnautilus.it': 'ilnautilus',
#  'https://kenyan-post.com': 'kenyan-post',
#  'https://lapagina.com.sv': 'lapagina',
#  'https://www.napi.hu': 'napi',
#  'https://euractiv.it': 'euractiv-it',
#  'https://www.europeantimes.news': 'europeantimes',
#  'https://mfame.guru': 'mfame',
#  'https://www.palo.gr': 'palo-gr',
#  'https://www.kibrispostasi.com': 'kibrispostasi',
#  'https://www.newmoney.gr': 'newmoney',
#  'https://www.ecodibergamo.it': 'ecodibergamo',
#  'https://ladiscussione.com/tag/diritti-umani/': 'ladiscussione',
#  'https://www.leparisien.fr': 'leparisien',
#  'https://news.am': 'news-am',
#  'https://www.finanzen.net': 'finanzen',
#  'https://www.diepresse.com': 'diepresse',
#  'https://www.ethnos.gr': 'ethnos',
#  'https://www.segabg.com': 'sega',
#  'https://www.epe.es': 'epe',
#  'https://www.esquire.com': 'esquire',
#  'https://news.un.org': 'news-un-es',
#  'https://www.pap.pl': 'pap',
#  'https://www.radiofrance.fr': 'radiofrance',
#  'https://www.finanzen.at': 'finanzen-at',
#  'https://www.magyarhirlap.hu': 'magyarhirlap',
#  'https://de.finance.yahoo.com': 'news-yahoo-de',
#  'https://www.prensalibre.com': 'prensalibre',
#  'https://www.respekt.cz': 'respekt',
#  'https://www.guatevision.com': 'guatevision',
#  'https://www.stolitsa.ee': 'stolitsa',
#  'https://www.naftikachronika.gr': 'naftikachronika',
#  'http://markets.businessinsider.com': 'markets-businessinsider',
#  'https://www.news-gazette.com': 'news-gazette',
#  'https://www.news-herald.com': 'news-herald',
#  'https://www.prignitzer.de': 'prignitzer',
#  'https://safety4sea.com': 'safety4sea',
#  'https://www.voanews.com': 'voanews',
#  'https://www.europapress.es': 'epagro',
#  'https://www.europeanbusiness.gr': 'europeanbusiness',
#  'https://jyllands-posten.dk': 'jp',
#  'https://kronikaonline.ro': 'kronika',
#  'https://maldita.es': 'maldita',
#  'https://www.nxtmine.com': 'nxtmine',
#  'https://viborg-folkeblad.dk': 'viborg-folkeblad',
#  'https://wsau.com': 'wsau',
#  'http://www.afn.by': 'afn',
#  'https://agenda.ge': 'agenda-ge',
#  'https://news.day.az': 'day',
#  'http://www.ecopress.by': 'ecopress',
#  'https://www.globaltimes.cn/page/202203/1254440.shtml': 'globaltimes',
#  'https://www.hoybolivia.com': 'hoybolivia',
#  'https://hoydia.com.ar': 'hoydia',
#  'https://knowridge.com': 'knowridge',
#  'https://noticialdia.com': 'noticiaaldia',
#  'https://realnoevremya.ru': 'realnoevremya',
#  'https://www.vol.at': 'Vorarlberg',
#  'https://www.businessinsider.co.za': 'businessinsider-za',
#  'https://demokracija.si': 'demokracija',
#  'https://elcorreoweb.es': 'elcorreoweb',
#  'https://elpais.bo': 'elpaisonline',
#  'https://faktor.ba': 'faktor-ba',
#  'https://www.ekathimerini.com': 'kathimerini-en',
#  'https://www.nytimes.com': 'nytimes',
#  'https://www.eastbaytimes.com': 'eastbaytimes',
#  'https://www.notiulti.com': 'notiulti',
#  'https://www.abc.net.au': 'abc-au',
#  'https://www.expreso.ec': 'diario-expreso',
#  'https://www.miragenews.com': 'miragenews',
#  'https://www.cmjornal.pt': 'destak',
#  'https://www.oann.com': 'oann',
#  'https://noticias.r7.com': 'noticias-r7',
#  'https://www.lepoint.fr': 'LePoint',
#  'https://www.bd.nl': 'brabantsdagblad',
#  'https://www.pzc.nl': 'pzc',
#  'https://ryukyushimpo.jp': 'ryukyushimpo',
#  'https://www.gelderlander.nl': 'gelderlander',
#  'https://www.at-s.com': 'shizuokaonline',
#  'https://www.bndestem.nl': 'bndestem',
#  'https://www.alternet.org': 'alternet',
#  'https://www.tokyo-np.co.jp': 'tokyo-np',
#  'https://www.skai.gr': 'skai',
#  'https://www.destentor.nl': 'destentor',
#  'https://www.airforcetimes.com': 'airforcetimes',
#  'https://www.trouw.nl': 'trouw',
#  'https://www.kristeligt-dagblad.dk': 'kristeligt-dagblad',
#  'https://pulitzercenter.org': 'pulitzercenter',
#  'https://report.az': 'report-az',
#  'https://news.sky.com': 'skynews',
#  'https://www.agi.it': 'agi',
#  'https://www.berlingske.dk': 'berlingske',
#  'http://baijiahao.baidu.com': 'baidu',
#  'https://www.militarytimes.com': 'militarytimes',
#  'https://www.armytimes.com': 'armytimes',
#  'https://www.hz.de': 'hz-de',
#  'https://www.ka-news.de': 'ka-news',
#  'https://www.donaukurier.de': 'donaukurier',
#  'https://news.trust.org': 'trust',
#  'https://nachrichtend.com': 'nachrichtend',
#  'https://www.nbc12.com': 'nbc12',
#  'https://www.shz.de': 'shz',
#  'https://chinapost.nownews.com': 'ChinaPost',
#  ...}

# %%
import json

with open("data/linkmapping.json", "w") as file:
    json.dump(basemapped_to_link, file, indent = 4)
